# %%
import numpy as np
from IPython.display import display
import pandas as pd

# %%
mobile = pd.read_csv("hw_mobile.csv")
df_mobile = mobile.copy()

# %%
# 1.
df_mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3323 non-null   float64
#  7   Total day calls         3323 non-null   float64
#  8   Total day charge        3315 non-null   float64
#  9   Total eve minutes       3324 non-null   float64
#  10  Total eve calls         3325 non-null   float64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3332 non-null   float64
# ...

# %%
# 2.
df_mobile.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
# 3.
display(df_mobile.head())

display(df_mobile.tail())
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
# 4.
df_mobile[['State']].head()
# Out:
#   State
# 0    KS
# 1    OH
# 2    NJ
# 3    OH
# 4    OK

# %%
# 5.
df_mobile[['State', 'International plan']].head()
# Out:
#   State International plan
# 0    KS                 No
# 1    OH                 No
# 2    NJ                 No
# 3    OH                Yes
# 4    OK                Yes

# %%
# 6.
display(df_mobile[df_mobile['International plan'] == 'Yes'].head())
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 7    MO             147        415                Yes              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
# 5                      0              223.4             98.0
# 7                      0              157.0             79.0
# 9                     37              258.6             84.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3             50.90               61.9             88.0              5.26
# ...

# %%
# 7.
display(df_mobile[(df_mobile['International plan'] == 'Yes') & (df_mobile['Churn'] == True)].head())
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 41     MD             135        408                Yes             Yes
# 115    ME              36        510                Yes             Yes
# 144    VT             117        408                Yes              No
# 198    ME             131        510                Yes             Yes
# 214    FL              70        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 41                      41              173.1             85.0
# 115                     42              196.8             89.0
# 144                      0              167.1             86.0
# 198                     26              292.9            101.0
# 214                      0              226.7             98.0
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# 8.
display(df_mobile.head(20).iloc[::2])
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 0     KS             128        415                 No             Yes
# 2     NJ             137        415                 No              No
# 4     OK              75        415                Yes              No
# 6     MA             121        510                 No             Yes
# 8     LA             117        408                 No              No
# 10    IN              65        415                 No              No
# 12    IA             168        408                 No              No
# 14    IA              62        415                 No              No
# 16    ID              85        408                 No             Yes
# 18    VA              76        510                 No             Yes
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 0                      25              265.1            110.0
# ...

# %%
# 9.
df_mobile.set_index('State', inplace=True)
df_mobile

display(df_mobile.loc['LA'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14996\515423893.py in ?()
#       1 # 9.
# ----> 2 df_mobile.set_index('State', inplace=True)
#       3 df_mobile
#       4
#       5 display(df_mobile.loc['LA'])
#
# C:\python\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['State'] are in the columns"

# %%
# 10.
df_mobile.drop(columns = ['Area code']).head()
# df_mobile.drop('Area code', axis=1)
# Out:
#        Account length International plan Voice mail plan  \
# State
# KS                128                 No             Yes
# OH                107                 No             Yes
# NJ                137                 No              No
# OH                 84                Yes              No
# OK                 75                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# KS                45.07              197.4             99.0             16.78
# ...

# %%
# 11.
df_mobile['traveler'] = df_mobile['International plan'].apply(lambda x: 'tourist' if x == 'Yes' else 'homer')
df_mobile[['International plan', 'traveler']].head(10)
# Out:
#       International plan traveler
# State
# KS                    No    homer
# OH                    No    homer
# NJ                    No    homer
# OH                   Yes  tourist
# OK                   Yes  tourist
# AL                   Yes  tourist
# MA                    No    homer
# MO                   Yes  tourist
# LA                    No    homer
# WV                   Yes  tourist

# %%
# 12.
df_mobile['talker_type'] = df_mobile.apply(lambda row: 'day person' if row['Total day minutes'] >= row['Total night minutes'] else 'night person', axis=1)
df_mobile[['Total day minutes', 'Total night minutes', 'talker_type']]
# Out:
#        Total day minutes  Total night minutes   talker_type
# State
# KS                 265.1                244.7    day person
# OH                 161.6                254.4  night person
# NJ                 243.4                162.6    day person
# OH                 299.4                196.9    day person
# OK                 166.7                186.9  night person
# ...                  ...                  ...           ...
# AZ                 156.2                279.1  night person
# WV                 231.1                191.3    day person
# RI                 180.8                191.9  night person
# CT                 213.8                139.2    day person
# TN                 234.4                241.4  night person
#
# [3333 rows x 3 columns]
